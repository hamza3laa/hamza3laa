# %% [markdown]
# <a href="https://colab.research.google.com/github/hamza3laa/hamza3laa/blob/main/USHousingUseCase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine learning/Datasets/usa_housing.csv')

# %%
df.head(3)
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
#
# [3 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe().T
# Out:
#                                count          mean  ...           75%           max
# Avg. Area Income              5000.0  6.858311e+04  ...  7.578334e+04  1.077017e+05
# Avg. Area House Age           5000.0  5.977222e+00  ...  6.650808e+00  9.519088e+00
# Avg. Area Number of Rooms     5000.0  6.987792e+00  ...  7.665871e+00  1.075959e+01
# Avg. Area Number of Bedrooms  5000.0  3.981330e+00  ...  4.490000e+00  6.500000e+00
# Area Population               5000.0  3.616352e+04  ...  4.286129e+04  6.962171e+04
# Price                         5000.0  1.232073e+06  ...  1.471210e+06  2.469066e+06
#
# [6 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True , cmap='cividis_r')

# %%
sns.regplot( df['Avg. Area Income'] ,df['Price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.describe().columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %%
X = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']].values
y = df['Price'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train ,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2.15747381e+01, 1.65896482e+05, 1.20402962e+05, 1.04865179e+03,
#        1.52530899e+01])

# %%
model.intercept_
# Out:
# -2636149.4728181013

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test, y_pred))
# Out:
# 0.9191926277262267
